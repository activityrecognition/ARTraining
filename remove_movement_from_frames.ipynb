# %%
from PIL import Image
import numpy
from matplotlib.pyplot import imshow

img = Image.open("./../dataset_thermalRaw/14_tim/1/Users_fede.polacov_unkown_2016-06-20_16%3A41%3A08.000000_2/5.png")
imshow(numpy.asarray(img))

r, g, b = img.split()

# %%
# %matplotlib inline
im = Image.merge("RGB", (r, r, r))
imshow(numpy.asarray(im))

# %%
# %matplotlib inline
im2 = Image.merge("RGB", (g, g, g))
imshow(numpy.asarray(im2))

# %%
# %matplotlib inline
im3 = Image.merge("RGB", (b, b, b))
imshow(numpy.asarray(im3))
